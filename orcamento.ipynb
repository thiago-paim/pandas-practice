# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:,.2f}'.format

dataset_path = 'preprocessed_datasets'
dataset_name = 'OrcamentoDespesa_2022-10-25 01:33:10.092255.csv'

df = pd.read_csv(f"{dataset_path}/{dataset_name}", sep=';')

df.sample(5)
# Out:
#         exercicio                                nome_orgao_superior  \
# 85525        2017  Ministério da Ciência, Tecnologia, Inovações e...
# 161932       2019   Ministério da Mulher, Família e Direitos Humanos
# 73621        2016                      Ministério de Minas e Energia
# 195813       2021                             Ministério da Educação
# 53091        2015                               Ministério da Defesa
#
#                                    nome_orgao_subordinado  \
# 85525   Conselho Nacional de Desenvolvimento Científic...
# 161932  Ministério da Mulher, Família e Direitos Human...
# 73621          Companhia de Pesquisa de Recursos Minerais
# 195813                     Universidade Federal do Cariri
# 53091                              Comando da Aeronáutica
#
#                            nome_unidade_orcamentaria            nome_funcao  \
# 85525   CONSELHO NAC.DE DESENV.CIENTIF.E TECNOLOGICO   Ciência e Tecnologia
# 161932         MINISTERIO DOS DIREITOS HUMANOS - MDH  Direitos da cidadania
# 73621     COMPANHIA DE PESQUISA DE RECURSOS MINERAIS     Encargos especiais
# 195813         UNIVERSIDADE FEDERAL DO CARIRI - UFCA               Educação
# 53091                         COMANDO DA AERONAUTICA     Previdência social
#
#                                    nome_subfuncao  \
# 85525    Desenvolvimento tecnológico e engenharia
# 161932  Direitos individuais, coletivos e difusos
# 73621                   Outros encargos especiais
# 195813                             Atenção básica
# 53091                        Previdência especial
#
#                                nome_programa_orcamentario  \
# 85525                      CIENCIA, TECNOLOGIA E INOVACAO
# 161932  PROMOCAO DA IGUALDADE RACIAL E SUPERACAO DO RA...
# 73621   OPERACOES ESPECIAIS: CUMPRIMENTO DE SENTENCAS ...
# 195813  PROGRAMA DE GESTAO E MANUTENCAO DO PODER EXECU...
# 53091   PROGRAMA DE GESTAO E MANUTENCAO DO MINISTERIO ...
#
#                                                 nome_acao  \
# 85525   CIENCIA, TECNOLOGIA E INOVACAO NO CENTRO DE TE...
# 161932  FOMENTO A ACOES AFIRMATIVAS E OUTRAS INICIATIV...
# 73621   SENTENCAS JUDICIAIS DEVIDAS POR EMPRESAS ESTATAIS
# 195813  ASSISTENCIA MEDICA E ODONTOLOGICA AOS SERVIDOR...
# 53091   INDENIZACAO A ANISTIADOS POLITICOS EM PRESTACA...
#
#        nome_categoria_economica          nome_grupo_despesa  \
# 85525        DESPESAS CORRENTES   Outras Despesas Correntes
# 161932       DESPESAS CORRENTES   Outras Despesas Correntes
# 73621        DESPESAS CORRENTES   Outras Despesas Correntes
# 195813       DESPESAS CORRENTES   Outras Despesas Correntes
# 53091        DESPESAS CORRENTES  Pessoal e Encargos Sociais
#
#                                nome_elemento_despesa  orcamento_inicial  \
# 85525                Auxílio Financeiro a Estudantes         250,000.00
# 161932  Outros Serviços de Terceiros - Pessoa Física         149,955.45
# 73621                                  Não informado         -18,776.73
# 195813                                 Não informado         -59,128.60
# 53091                                  Não informado     -16,090,556.00
#
#         orcamento_atualizado  orcamento_empenhado  orcamento_realizado
# 85525             250,000.00           250,000.00                 0.00
# 161932            149,955.45           128,455.45           128,455.45
# 73621              11,223.27                 0.00                 0.00
# 195813              5,901.40                 0.00                 0.00
# 53091                   0.00                 0.00                 0.00

# %%
# Calcula diferença entre orçamentos inicial e realizado
orcamento_diff = df.apply(lambda row: row['orcamento_realizado'] - row['orcamento_inicial'], axis=1)
df['dif_orcamento_realizado_inicial'] = orcamento_diff

df.describe()
# Out:
#        exercicio    orcamento_inicial  orcamento_atualizado  \
# count 214,908.00           214,908.00            214,908.00
# mean    2,017.44       119,194,524.84        125,164,324.44
# std         2.30     6,669,963,694.36      6,388,024,172.59
# min     2,014.00  -481,026,132,218.00     -7,933,774,178.00
# 25%     2,015.00            17,233.75             14,000.00
# 50%     2,017.00           250,000.02            203,421.57
# 75%     2,019.00         2,315,899.98          1,850,000.00
# max     2,021.00 1,399,235,985,553.00  1,399,235,985,553.00
#
#        orcamento_empenhado  orcamento_realizado  \
# count           214,908.00           214,908.00
# mean        100,159,849.12        95,226,784.18
# std       5,038,037,035.27     5,087,666,799.46
# min        -201,664,633.00    -1,559,690,000.00
# 25%                   0.00                 0.00
# 50%              33,716.32            10,990.91
# 75%             855,316.51           459,944.64
# max   1,130,593,676,561.26 1,248,816,572,989.47
#
#        dif_orcamento_realizado_inicial
# count                       214,908.00
# mean                    -23,967,740.66
# std                   2,676,058,895.07
# min                -541,585,094,367.80
# 25%                        -658,004.45
# 50%                         -40,421.70
# 75%                               0.00
# max                 481,026,132,218.00

# %%
"""
TODO: Lidar valores negativos de orcamento
"""

# print(df.shape)
# df.query('orcamento_inicial < 0').orcamento_inicial.count()
# Out:
# '\nTODO: Lidar valores negativos de orcamento\n'

# %%
# Exibe 5 orgãos mais comuns do orçamento
most_common_organs = df['nome_orgao_superior'].value_counts() / df.shape[0] * 100
print(most_common_organs[:5])

print(sns.histplot(df.orcamento_inicial, alpha=0.4, kde=True, kde_kws={"cut": 3}))
# Out:
# Ministério da Educação                   41.55
# Ministério da Defesa                      7.17
# Ministério da Saúde                       5.69
# Ministério da Economia                    5.55
# Ministério do Desenvolvimento Regional    5.01
# Name: nome_orgao_superior, dtype: float64

# %%
# Orçamento inicial total para cada orgão superior
initial_budget_per_organ = df.groupby('nome_orgao_superior')['orcamento_realizado'].agg([len, sum])

# Valor médio dos orçamentos por orgão superior
avg_budget = initial_budget_per_organ.apply(lambda row: row['sum'] / row['len'], axis=1)
initial_budget_per_organ['avg_budget'] = avg_budget
initial_budget_per_organ.sort_values('avg_budget', ascending=False)

# %%
df.groupby('nome_orgao_superior')['orcamento_realizado'].agg([len, sum]).sort_values('sum', ascending=False)
